# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv ('data.csv')

# %%
df.drop(['Unnamed: 32', 'id','perimeter_mean', 'radius_mean', 'compactness_mean', 'concave points_mean', 'radius_se', 'perimeter_se', 'radius_worst', 'perimeter_worst', 'compactness_worst', 'concave points_worst', 'compactness_se', 'concave points_se', 'texture_worst', 'area_worst'], axis=1, inplace=True)

# %%
df
# Out:
#     diagnosis  texture_mean  area_mean  smoothness_mean  concavity_mean  \
# 0           M         10.38     1001.0          0.11840         0.30010
# 1           M         17.77     1326.0          0.08474         0.08690
# 2           M         21.25     1203.0          0.10960         0.19740
# 3           M         20.38      386.1          0.14250         0.24140
# 4           M         14.34     1297.0          0.10030         0.19800
# ..        ...           ...        ...              ...             ...
# 564         M         22.39     1479.0          0.11100         0.24390
# 565         M         28.25     1261.0          0.09780         0.14400
# 566         M         28.08      858.1          0.08455         0.09251
# 567         M         29.33     1265.0          0.11780         0.35140
# 568         B         24.54      181.0          0.05263         0.00000
#
#      symmetry_mean  fractal_dimension_mean  texture_se  area_se  \
# ...

# %%
df['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
plt.figure(figsize=(5,5))
sns.countplot(data=df, x='diagnosis', palette=['blue','purple'])
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df['diagnosis'].replace({"M":1,"B":0},inplace=True)

# %%
df.shape
# Out:
# (569, 17)

# %%
df.describe()
# Out:
#         diagnosis  texture_mean    area_mean  smoothness_mean  concavity_mean  \
# count  569.000000    569.000000   569.000000       569.000000      569.000000
# mean     0.372583     19.289649   654.889104         0.096360        0.088799
# std      0.483918      4.301036   351.914129         0.014064        0.079720
# min      0.000000      9.710000   143.500000         0.052630        0.000000
# 25%      0.000000     16.170000   420.300000         0.086370        0.029560
# 50%      0.000000     18.840000   551.100000         0.095870        0.061540
# 75%      1.000000     21.800000   782.700000         0.105300        0.130700
# max      1.000000     39.280000  2501.000000         0.163400        0.426800
#
#        symmetry_mean  fractal_dimension_mean  texture_se     area_se  \
# count     569.000000              569.000000  569.000000  569.000000
# mean        0.181162                0.062798    1.216853   40.337079
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
matrix=df.corr().round(2)
mask = np.triu(np.ones_like(matrix,dtype=bool))

plt.figure(figsize=(20,20))
sns.heatmap(matrix, annot=True, vmin=-1, vmax=1, cmap='vlag', mask=mask)
# Out:
# <Axes: >

# %%
df
# Out:
#      diagnosis  texture_mean  area_mean  smoothness_mean  concavity_mean  \
# 0            1         10.38     1001.0          0.11840         0.30010
# 1            1         17.77     1326.0          0.08474         0.08690
# 2            1         21.25     1203.0          0.10960         0.19740
# 3            1         20.38      386.1          0.14250         0.24140
# 4            1         14.34     1297.0          0.10030         0.19800
# ..         ...           ...        ...              ...             ...
# 564          1         22.39     1479.0          0.11100         0.24390
# 565          1         28.25     1261.0          0.09780         0.14400
# 566          1         28.08      858.1          0.08455         0.09251
# 567          1         29.33     1265.0          0.11780         0.35140
# 568          0         24.54      181.0          0.05263         0.00000
#
#      symmetry_mean  fractal_dimension_mean  texture_se  area_se  \
# ...

# %%
X=df.drop('diagnosis', axis=1)
y=df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
clf=LogisticRegression()
parameters = {'C':[1, 10, 20, 30, 40, 50, 70, 100, 200, 300], 
              'penalty':['l1','l2','elasticnet'], 'max_iter':[100,200,300]}
clf_reg = GridSearchCV(clf, param_grid=parameters, scoring='accuracy', cv=5,)

# %%
clf_reg.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1, 10, 20, 30, 40, 50, 70, 100, 200, 300],
#                          'max_iter': [100, 200, 300],
#                          'penalty': ['l1', 'l2', 'elasticnet']},
#              scoring='accuracy')

# %%
print(clf_reg.best_params_)
# Out:
# {'C': 200, 'max_iter': 300, 'penalty': 'l2'}

# %%
print(clf_reg.best_score_)
# Out:
# 0.952734107997266

# %%
y_pred=clf_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy=accuracy_score(y_pred, y_test)
accuracy
# Out:
# 0.973404255319149

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       118
#            1       0.99      0.94      0.96        70
#
#     accuracy                           0.97       188
#    macro avg       0.98      0.97      0.97       188
# weighted avg       0.97      0.97      0.97       188
